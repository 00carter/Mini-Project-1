# %%
import pandas as pd
from superstore import utilities
try:
    df = pd.read_excel("Superstore 2019.xls", index_col="Row ID")
except FileNotFoundError:
    print("Change file name to Superstore 2019.xls")

df

# cleaner = utilities.Cleaner(df)
# df = cleaner.clean()
# df.info()
# df[df["Postal Code"].isna()][["City", "State"]]

# profit, discount, quantity, sales = df["Profit"].describe(), df["Discount"].describe(), df["Quantity"].describe(), df["Sales"].describe()
# profit
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64
