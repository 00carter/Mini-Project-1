# %%
import pandas as pd
from superstore.utilities import Cleaner, FeatureEngineering, Visualization

try:
    df = pd.read_excel("Superstore 2019.xls", index_col="Row ID")
except FileNotFoundError:
    print("Change file name to Superstore 2019.xls")

cleaner = Cleaner(df)
df = cleaner.clean()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9993 entries, 1 to 9994
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        9993 non-null   str
#  1   Order Date      9993 non-null   datetime64[us]
#  2   Ship Date       9993 non-null   datetime64[us]
#  3   Ship Mode       9993 non-null   str
#  4   Customer ID     9993 non-null   str
#  5   Customer Name   9993 non-null   str
#  6   Segment         9993 non-null   str
#  7   Country/Region  9993 non-null   str
#  8   City            9993 non-null   str
#  9   State           9993 non-null   str
#  10  Postal Code     9993 non-null   Int64
#  11  Region          9993 non-null   str
#  12  Product ID      9993 non-null   str
#  13  Category        9993 non-null   str
#  14  Sub-Category    9993 non-null   str
#  15  Product Name    9993 non-null   str
#  16  Sales           9993 non-null   float64
#  17  Quantity        9993 non-null   int64
# ...

# %%
print(cleaner.get_outliers("Profit"))
# Out:
# 1881 outliers in Profit column

# %%
print(cleaner.get_outliers("Sales"))
# Out:
# 1167 outliers in Sales column

# %%
fe = FeatureEngineering(df)
df = fe.add_columns()
df.head(1)
# Out:
#               Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# Row ID
# 1       CA-2018-152156 2018-11-08 2018-11-11  Second Class    CG-12520
#
#        Customer Name   Segment Country/Region       City     State  ...  \
# Row ID                                                              ...
# 1        Claire Gute  Consumer  United States  Henderson  Kentucky  ...
#
#          Category Sub-Category                       Product Name   Sales  \
# Row ID
# 1       Furniture    Bookcases  Bush Somerset Collection Bookcase  261.96
#
#        Quantity Discount   Profit  Profit Margin  Shipping Duration  \
# Row ID
# 1             2      0.0  41.9136           0.16             3 days
#
#         Sales Performance Category
# Row ID
# 1                        Very High
#
# [1 rows x 23 columns]

# %%
v = Visualization(df)
v.show_all()
